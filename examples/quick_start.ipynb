# %%
import pandas as pd
import numpy as np
import ineqpy
# Out:
# IneqPy: A PYTHON PACKAGE TO QUANTITATIVE ANALYSIS OF INEQUALITY LODADED

# %% [markdown]
# # First-steps

# %%
income = np.random.randn(10000,1) +
